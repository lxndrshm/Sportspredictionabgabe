# %%
# Install the needed packages
# %pip install pathlib pandas numpy tensorflow tensorboard
# Out:
# Requirement already satisfied: pathlib in /home/dirk/.local/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: pandas in /home/dirk/.local/lib/python3.8/site-packages (1.3.5)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (1.17.4)
# Requirement already satisfied: tensorflow in /home/dirk/.local/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: tensorboard in /home/dirk/.local/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas) (2.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas) (2019.3)
# Requirement already satisfied: astunparse>=1.6.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: h5py>=2.9.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (4.0.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: libclang>=9.0.1 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/dirk/.local/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/lib/python3/dist-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorboard) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/dirk/.local/lib/python3.8/site-packages (from tensorboard) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/dirk/.local/lib/python3.8/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/dirk/.local/lib/python3.8/site-packages (from tensorboard) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard) (45.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/dirk/.local/lib/python3.8/site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard) (3.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorboard) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/dirk/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/dirk/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/dirk/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/dirk/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.2.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/dirk/.local/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages.
import os
import signal
import tempfile
from pathlib import Path
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorboard as tb

# %%
# Define parameters.
LOGS_PATH = '../logs'
DATA_PATH = '../data/own_data_preparation.csv'
RESULT_COLUMN = 'result_team1'
DUMMY_COLUMNS = ['team1', 'team2']
NORMAILZE_COLUMNS = ['points', 'squard',
    'average_age', 'average_market_value_in_euro', 'total_market_value_in_euro',
    'rank_last_season', 'points_last_season_all', 'points_last_season']
WITH_TEAMS = True
VALIDATION_SIZE = 0.2
ACTIVATION_FUNCTIONS = ['sigmoid', 'tanh', 'relu', 'relu6', 'softsign', 'linear']
LOSS_FUNCTION = 'sparse_categorical_crossentropy'
OPTIMIZER_FUNCTION = 'Adam'
METRICS = 'sparse_categorical_accuracy'
EPOCHS = 300
BATCH_SIZE = 32
TITLE = 'activation_with_teams'

TENSORBOARD_PROCESS = 'tensorboard'
TENSORBOARD_SERVER = 'localhost'
TENSORBOARD_PORT = 6008

LOGS_PATH = os.path.join(LOGS_PATH, TITLE)

# %%
# Set up tensorboard.
# %load_ext tensorboard
logs = Path(LOGS_PATH)
logs.mkdir(mode=0o777, parents=True, exist_ok=True)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# Load the data set.
data = pd.read_csv(DATA_PATH, delimiter=',', decimal='.')

# Create the difference between team1 and team2 for each feature.
for column in NORMAILZE_COLUMNS:
    data[column] = data[column + '_team1'] - data[column + '_team2']

# Normalize column using the max value for each column.
for column in NORMAILZE_COLUMNS:
    max_value = data[column].max()
    data[column] = data[column].apply(lambda x: x / max_value)

# Get the wanted columns and create dummy columns for the teams.
if WITH_TEAMS:
    data = data.loc[:, DUMMY_COLUMNS + NORMAILZE_COLUMNS + [RESULT_COLUMN]]
    data = pd.get_dummies(data, columns=DUMMY_COLUMNS)
else:
    data = data.loc[:, NORMAILZE_COLUMNS + [RESULT_COLUMN]]

# Drop rows with nan values.
data = data.dropna()

# Split the data set.
split_index = int(len(data) * VALIDATION_SIZE)
data = data.sample(frac=1)
data_train = data[split_index:]
data_valid = data[:split_index]

par_train = data_train.loc[:, data_train.columns != RESULT_COLUMN]
res_train = data_train.loc[:, [RESULT_COLUMN]]
par_valid = data_valid.loc[:, data_train.columns != RESULT_COLUMN]
res_valid = data_valid.loc[:, [RESULT_COLUMN]]

if WITH_TEAMS:
    dummies = [key for key in par_train.keys() if 'team' in key]

data.head()
# Out:
#         points    squard  average_age  average_market_value_in_euro  \
# 16   -0.017857  0.333333    -0.046512                     -0.003854
# 705  -0.142857 -0.111111     0.418605                     -0.067116
# 160  -0.160714  0.444444    -0.209302                     -0.262042
# 465  -0.196429 -0.166667     0.348837                     -0.033719
# 1575 -0.267857  0.277778    -0.325581                     -1.000000
#
#       total_market_value_in_euro  rank_last_season  points_last_season_all  \
# 16                      0.010333             -0.45                0.147727
# 705                    -0.087855              0.45               -0.488636
# 160                    -0.265767              0.20               -0.318182
# 465                    -0.050782              0.20               -0.193182
# 1575                   -0.907312              0.95               -0.886364
#
#       points_last_season  result_team1  team1_1. FC Nürnberg  ...  \
# 16              0.106557           1.0                     0  ...
# 705            -0.064083           2.0                     0  ...
# 160            -0.025501           1.0                     0  ...
# 465            -0.015483           1.0                     0  ...
# 1575           -0.213115           0.0                     0  ...
#
#       team2_SC Freiburg  team2_SC Paderborn  team2_SV Darmstadt 98  \
# 16                    0                   0                      0
# 705                   0                   0                      0
# 160                   0                   0                      0
# 465                   0                   0                      0
# 1575                  0                   0                      0
#
#       team2_Schalke 04  team2_SpVgg Greuther Fürth  team2_TSG Hoffenheim  \
# 16                   0                           0                     1
# 705                  0                           0                     0
# 160                  0                           0                     0
# 465                  0                           0                     1
# 1575                 0                           0                     0
#
#       team2_VfB Stuttgart  team2_VfL Bochum  team2_VfL Wolfsburg  \
# 16                      0                 0                    0
# 705                     0                 0                    0
# 160                     0                 0                    0
# 465                     0                 0                    0
# 1575                    0                 0                    0
#
#       team2_Werder Bremen
# 16                      0
# 705                     0
# 160                     0
# 465                     0
# 1575                    0
#
# [5 rows x 63 columns]

# %%
# Convert data frames to numpy arrays.
res_train = res_train.to_numpy()
res_valid = res_valid.to_numpy()

print(par_train.shape)
print(res_train.shape)
print(par_valid.shape)
print(res_valid.shape)
# Out:
# (1347, 62)
# (1347, 1)
# (336, 62)
# (336, 1)

# %%
def defineModel(input_dim, activation):
    # Define the model
    nodes = input_dim*2-1
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(nodes, activation=activation, input_dim=input_dim),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Dense(3, activation='softmax')
    ])

    # Compile the model.
    model.compile(loss=LOSS_FUNCTION, optimizer=OPTIMIZER_FUNCTION, metrics=[METRICS])

    return model

# %%
def runModel(model, x_train, x_valid, y_train, y_valid, title):
    # Define callback function for writing data for tensorBoard
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=os.path.join(LOGS_PATH, title), histogram_freq=1)

    # Run the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        validation_data=(x_valid, y_valid),
        callbacks=[tensorboard_callback],
        verbose=0
    )

    return history

# %%
sel_train = par_train.to_numpy()
sel_valid = par_valid.to_numpy()

for activation in ACTIVATION_FUNCTIONS:
    runModel(defineModel(sel_train.shape[1], activation), sel_train, sel_valid, res_train, res_valid, activation)

# %%
# Kill the existing tensorboard process and delete the tensorflow temp folder. After this start a new tensorboard process.
try:    
    # Iterating through each instance of the process.
    for line in os.popen("ps ax | grep " + TENSORBOARD_PROCESS + " | grep -v grep"):
        fields = line.split()
            
        # Extracting Process ID from the output.
        pid = fields[0]
            
        # Terminating process.
        os.kill(int(pid), signal.SIGKILL)

    # Delete tensorboard temp folder.
    tb_temp_folder = os.path.join(tempfile.gettempdir(), '.tensorboard-info')
    os.system("rm -rf "+tb_temp_folder)
    print("Process Successfully terminated") 
except Exception as e:
    print(e)

# %tensorboard --logdir $LOGS_PATH --host $TENSORBOARD_SERVER --port $TENSORBOARD_PORT
# Out:
# Process Successfully terminated
#       <iframe id="tensorboard-frame-84338936c9640d1d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-84338936c9640d1d");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
